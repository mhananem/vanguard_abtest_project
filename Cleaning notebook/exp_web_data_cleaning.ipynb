# %% [markdown]
# # Cleaning the Data
# -  data cleaning of demo + experiment files

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import os

# %%
os.getcwd()  # this prints your current working directory
# Out:
# '/Users/hanane/Ironhack/vanguard_abtest_project'

# %%
os.listdir('raw_data')
# Out:
# ['df_final_experiment_clients.csv',
#  'df_final_demo.csv',
#  'df_final_web_data_pt_1.csv',
#  'df_final_web_data_pt_2.csv']

# %%
df_demo = pd.read_csv('clean_data/demo_exp_merged.csv')
df_exp = pd.read_csv('raw_data/df_final_experiment_clients.csv')
df_web1 = pd.read_csv('raw_data/df_final_web_data_pt_1.csv')
df_web2 = pd.read_csv('raw_data/df_final_web_data_pt_2.csv')

# %%
df_demo.head(5)
# Out:
#    client_id  client_tenure_yr  client_tenure_month  client_age   gender  \
# 0     836976               6.0                 73.0          60  Unknown
# 1    2304905               7.0                 94.0          58  Unknown
# 2    1439522               5.0                 64.0          32  Unknown
# 3    1562045              16.0                198.0          49     Male
# 4    5126305              12.0                145.0          33   Female
#
#    num_accts    balance  calls_6_mnth  logons_6_mnth Variation
# 0          2   45105.30             6              9      Test
# 1          2  110860.30             6              9   Control
# 2          2   52467.79             6              9      Test
# 3          2   67454.65             3              6      Test
# 4          2  103671.75             0              3   Control

# %% [markdown]
# ## df_exp cleaning

# %%
df_exp.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
df_exp.columns = df_exp.columns.str.lower().str.strip()

# %%
df_exp['variation'].value_counts(dropna=False)
# Out:
# variation
# Test       26968
# Control    23532
# NaN        20109
# Name: count, dtype: int64

# %%
df_exp.isnull().sum()
# Out:
# client_id        0
# variation    20109
# dtype: int64

# %%
df_exp = df_exp.dropna(subset=['variation'])
df_exp.isnull().sum()
# Out:
# client_id    0
# variation    0
# dtype: int64

# %%
df_exp.variation.value_counts()
# Out:
# variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
df_exp.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_exp.to_csv("clean_data/cleaned_experiment.csv",index=False)

# %%
df_exp.shape
# Out:
# (50500, 2)

# %% [markdown]
# ## df_web cleaning

# %%
df_web1.head(3)
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22

# %%
df_web2.head(3)
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48

# %%
#merging the two web datasets
df_web = pd.concat([df_web1, df_web2], axis=0 )

# %%
df_web.shape
# Out:
# (755405, 5)

# %%
df_web.duplicated().sum()
# Out:
# np.int64(10764)

# %%
df_web = df_web.drop_duplicates()
df_web.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_web.isnull().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_web.dtypes
# Out:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
df_web['date_time'] =pd.to_datetime(df_web['date_time'])
print(df_web.date_time.dtype)
# Out:
# datetime64[ns]

# %%
df_web['process_step'].value_counts()
# Out:
# process_step
# start      234999
# step_1     162797
# step_2     132750
# step_3     111589
# confirm    102506
# Name: count, dtype: int64

# %%
df_web.isnull().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_web.head(10)
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 5    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 6    9988021  580560515_7732621733  781255054_21935453173_531117       step_1
# 7    9988021  580560515_7732621733  781255054_21935453173_531117        start
# 8    8320017  39393514_33118319366  960651974_70596002104_312201      confirm
# 9    8320017  39393514_33118319366  960651974_70596002104_312201       step_3
#
#             date_time
# 0 2017-04-17 15:27:07
# 1 2017-04-17 15:26:51
# 2 2017-04-17 15:19:22
# 3 2017-04-17 15:19:13
# 4 2017-04-17 15:18:04
# 5 2017-04-17 15:17:15
# 6 2017-04-17 15:17:01
# 7 2017-04-17 15:16:22
# 8 2017-04-05 13:10:05
# 9 2017-04-05 13:09:43

# %%
df_web.to_csv("clean_data/cleaned_web.csv",index=False)

# %%
df_web.shape
# Out:
# (744641, 5)

# %%
df_exp.shape
# Out:
# (50500, 2)

# %% [markdown]
# ## Merging df_web and df_exp

# %%
df= df_exp.merge(df_web, on='client_id', how='inner')
print(df.shape)
# Out:
# (317235, 6)

# %%
df.variation.value_counts()
# Out:
# variation
# Test       176699
# Control    140536
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#    client_id variation            visitor_id                      visit_id  \
# 0    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 1    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 2    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 3    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 4    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 5    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 6    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 7    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 8    9988021      Test  580560515_7732621733  219729223_42518459208_211914
# 9    9988021      Test  580560515_7732621733  219729223_42518459208_211914
#
#   process_step           date_time
# 0       step_3 2017-04-17 15:27:07
# 1       step_2 2017-04-17 15:26:51
# 2       step_3 2017-04-17 15:19:22
# 3       step_2 2017-04-17 15:19:13
# 4       step_3 2017-04-17 15:18:04
# 5       step_2 2017-04-17 15:17:15
# 6       step_1 2017-04-17 15:17:01
# 7        start 2017-04-17 15:16:22
# 8        start 2017-04-12 18:54:43
# 9        start 2017-04-12 18:38:42

# %%
df.to_csv("clean_data/exp_web_merged.csv",index=False)

# %% [markdown]
# ## Merging all data
# # (Web, Exp & Demo)

# %%
df.head()
# Out:
#    client_id variation            visitor_id                      visit_id  \
# 0    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 1    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 2    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 3    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 4    9988021      Test  580560515_7732621733  781255054_21935453173_531117
#
#   process_step           date_time
# 0       step_3 2017-04-17 15:27:07
# 1       step_2 2017-04-17 15:26:51
# 2       step_3 2017-04-17 15:19:22
# 3       step_2 2017-04-17 15:19:13
# 4       step_3 2017-04-17 15:18:04

# %%
df_demo = pd.read_csv('clean_data/cleaned_demo.csv')
df_exp = pd.read_csv('clean_data/cleaned_experiment.csv')
df_web = pd.read_csv('clean_data/cleaned_web.csv')

# %%
df_demo.head()
# Out:
#    client_id  client_tenure_yr  client_tenure_month  client_age   gender  \
# 0     836976               6.0                 73.0          60  Unknown
# 1    2304905               7.0                 94.0          58  Unknown
# 2    1439522               5.0                 64.0          32  Unknown
# 3    1562045              16.0                198.0          49     Male
# 4    5126305              12.0                145.0          33   Female
#
#    num_accts    balance  calls_6_mnth  logons_6_mnth
# 0          2   45105.30             6              9
# 1          2  110860.30             6              9
# 2          2   52467.79             6              9
# 3          2   67454.65             3              6
# 4          2  103671.75             0              3

# %%
# step 1 : Merge web and experiment 

df1 = df_web.merge(df_exp, on='client_id', how='inner')
df1.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time variation
# 0  2017-04-17 15:27:07      Test
# 1  2017-04-17 15:26:51      Test
# 2  2017-04-17 15:19:22      Test
# 3  2017-04-17 15:19:13      Test
# 4  2017-04-17 15:18:04      Test

# %%
# step 2 : add demo data

df = df1.merge(df_demo, on='client_id', how='inner')
df.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time variation  client_tenure_yr  client_tenure_month  \
# 0  2017-04-17 15:27:07      Test               5.0                 64.0
# 1  2017-04-17 15:26:51      Test               5.0                 64.0
# 2  2017-04-17 15:19:22      Test               5.0                 64.0
# 3  2017-04-17 15:19:13      Test               5.0                 64.0
# 4  2017-04-17 15:18:04      Test               5.0                 64.0
#
#    client_age   gender  num_accts    balance  calls_6_mnth  logons_6_mnth
# 0          79  Unknown          2  189023.86             1              4
# 1          79  Unknown          2  189023.86             1              4
# 2          79  Unknown          2  189023.86             1              4
# 3          79  Unknown          2  189023.86             1              4
# 4          79  Unknown          2  189023.86             1              4

# %%
df.columns
# Out:
# Index(['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time',
#        'variation', 'client_tenure_yr', 'client_tenure_month', 'client_age',
#        'gender', 'num_accts', 'balance', 'calls_6_mnth', 'logons_6_mnth'],
#       dtype='object')
